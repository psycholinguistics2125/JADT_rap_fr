# %%
import pandas as pd

# %%
df = pd.read_csv("../data/20260225_enrich_dataset.csv")

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'artist',
#  'title',
#  'year',
#  'lyrics',
#  'lyrics_cleaned',
#  'born_in_france',
#  'url',
#  'birthdate_artist',
#  'age_artist',
#  'IRAMUTEQ_CLASSES',
#  'LDA_bigram_only',
#  'LDA_trigram_only',
#  'LDA_both',
#  'LDA_ngrams_only',
#  'BERTopic_camembert',
#  'BERTopic_e5',
#  'BERTopic_mpnet',
#  'IRAMUTEQ_evaluation_20260126_124001']

# %%
df['IRAMUTEQ_CLASSES'].value_counts().sum()
# Out:
# np.int64(115805)

# %%
# todo project : 
--> corriger distance de labbé
--> extraite coprus et clase pour chaque modèle
--> ecrire un script pour scraper meta data des rappeurs
--> ajouter des distances à partir des nouvelles meta data.
